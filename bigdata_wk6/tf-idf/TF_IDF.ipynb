# %%
# %%writefile mapper_1.py
#!/usr/bin/env python3

import sys
import re

sw_path = 'stop_words_en.txt'
stop_words = set()
stop_word_file = open(sw_path, 'r')
for stop_word in stop_word_file:
    stop_words.add(stop_word.strip())

for line in sys.stdin:
    try:
        article_id, text = line.rstrip().split('\t', 1)
        text = re.sub("^\W+|\W+$", "", text).lower()
        words = re.split("\W*\s+\W*", text)
    except ValueError as e:
        continue

    filtered_words = [x for x in words if x not in stop_words]
    word_count = len(filtered_words)
    for word in filtered_words:
            print(word + '_' + str(article_id) + '\t' + str(word_count) + '\t' + str(1))
# Out:
# Overwriting mapper_1.py

# %%
# %%writefile reducer_1.py
#!/usr/bin/env python3

import sys

current_word_current_doc_id = None
current_word_count = 0
current_doc_len = None


for line in sys.stdin:
    try:
        input_word_input_doc_id, input_doc_len, input_word_count = line.strip().split('\t', 2)
        input_word_count = int(input_word_count)
    except ValueError as e:
        continue

    if current_word_current_doc_id == input_word_input_doc_id:
        current_word_count += input_word_count
        current_doc_len = input_doc_len

    else:
        if current_word_current_doc_id is None:
            current_word_current_doc_id = input_word_input_doc_id
            current_word_count = input_word_count
            current_doc_len = input_doc_len

        else:
            current_word, current_doc_id = current_word_current_doc_id.split('_', 1)
            print(current_word + '\t' + current_doc_id + '\t' + current_doc_len + '\t' + str(current_word_count) + '\t' + str(1))

            current_word_current_doc_id = input_word_input_doc_id
            current_word_count = input_word_count
            current_doc_len = input_doc_len

if current_word_current_doc_id:
    current_word, current_doc_id = current_word_current_doc_id.split('_', 1)
    print(current_word + '\t' + current_doc_id + '\t' + current_doc_len + '\t' + str(current_word_count) + '\t' + str(1))
# Out:
# Overwriting reducer_1.py

# %%
# %%writefile mapper_2.py
#!/usr/bin/env python3

import sys

for line in sys.stdin:
    try:
        print(line)
    except ValueError as e:
        continue
# Out:
# Overwriting mapper_2.py

# %%
# %%writefile reducer_2.py
#!/usr/bin/env python3

import sys

current_word = None
current_doc_ids = []
current_doc_lens = []
current_word_counts = []
current_docs_with_word = 0


for line in sys.stdin:
    try:
        input_word, input_doc_id, input_doc_len, input_word_count, input_docs_with_word = line.strip().split('\t', 4)
        input_docs_with_word = int(input_docs_with_word)
    except ValueError as e:
        continue

    if current_word == input_word:
        current_doc_ids.append(input_doc_id)
        current_doc_lens.append(input_doc_len)
        current_word_counts.append(input_word_count)
        current_docs_with_word += input_docs_with_word

    else:
        if current_word is None:
            current_word = input_word
            current_doc_ids = [input_doc_id]
            current_doc_lens = [input_doc_len]
            current_word_counts = [input_word_count]
            current_docs_with_word = input_docs_with_word

        else:
            print(current_word + '\t' + ','.join(current_doc_ids) + '\t' + ','.join(current_doc_lens) + '\t'
                  + ','.join(current_word_counts) + '\t' + str(current_docs_with_word))

            current_word = input_word
            current_doc_ids = [input_doc_id]
            current_doc_lens = [input_doc_len]
            current_word_counts = [input_word_count]
            current_docs_with_word = input_docs_with_word

if current_word:
    print(current_word + '\t' + ','.join(current_doc_ids) + '\t' + ','.join(current_doc_lens) + '\t'
          + ','.join(current_word_counts) + '\t' + str(current_docs_with_word))
# Out:
# Overwriting reducer_2.py

# %%
# %%writefile find_labor_12.py
#!/usr/bin/env python3

import sys
import math

if __name__ == '__main__':

    check_word = 'labor'
    article_id = '12'

    for line in sys.stdin:
        input_word, input_doc_ids, input_doc_lens, input_word_counts, input_docs_with_word = line.strip().split('\t', 4)
        input_doc_ids_arr = input_doc_ids.split(',')
        input_doc_lens_arr = input_doc_lens.split(',')
        input_word_counts_arr = input_word_counts.split(',')

        if input_word == check_word:
            doc_id_index = input_doc_ids_arr.index(article_id)
            doc_len = int(input_doc_lens_arr[doc_id_index])
            word_count = int(input_word_counts_arr[doc_id_index])
            docs_with_word = int(input_docs_with_word)

            tf = word_count / doc_len
            idf = 1 / math.log(1 + docs_with_word)
            tf_idf = tf * idf

            print(tf_idf)
# Out:
# Overwriting find_labor_12.py

# %%
# %%bash
#
# OUT_DIR_1="week_6_tf_idf_a_"$(date +"%s%6N")
# OUT_DIR_2="week_6_tf_idf_b_"$(date +"%s%6N")
# NUM_REDUCERS_1=8
# NUM_REDUCERS_2=1
#
# # Code for first job
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -files mapper_1.py,reducer_1.py,/datasets/stop_words_en.txt \
#     -mapper 'python3 mapper_1.py' \
#     -reducer 'python3 reducer_1.py' \
#     -numReduceTasks ${NUM_REDUCERS_1} \
#     -input /data/wiki/en_articles_part \
#     -output ${OUT_DIR_1} > /dev/null
#
# # Code for second job
# yarn jar /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar \
#     -files mapper_2.py,reducer_2.py,find_labor_12.py \
#     -mapper 'python3 mapper_2.py' \
#     -reducer 'python3 reducer_2.py' \
#     -numReduceTasks ${NUM_REDUCERS_2} \
#     -input ${OUT_DIR_1} \
#     -output ${OUT_DIR_2} > /dev/null
#
# # Code for obtaining the results
# hdfs dfs -cat ${OUT_DIR_2}/part-00000 | python3 ./find_labor_12.py
#
# hdfs dfs -rm -r -skipTrash ${OUT_DIR_1}* > /dev/null
# hdfs dfs -rm -r -skipTrash ${OUT_DIR_2}* > /dev/null
# Out:
# 0.00035046896210986204
# 18/11/15 03:36:28 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/11/15 03:36:28 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/11/15 03:36:29 INFO mapred.FileInputFormat: Total input files to process : 1
# 18/11/15 03:36:29 INFO mapreduce.JobSubmitter: number of splits:2
# 18/11/15 03:36:29 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1542235673601_0003
# 18/11/15 03:36:29 INFO impl.YarnClientImpl: Submitted application application_1542235673601_0003
# 18/11/15 03:36:29 INFO mapreduce.Job: The url to track the job: http://81fb89c3c837:8088/proxy/application_1542235673601_0003/
# 18/11/15 03:36:29 INFO mapreduce.Job: Running job: job_1542235673601_0003
# 18/11/15 03:36:37 INFO mapreduce.Job: Job job_1542235673601_0003 running in uber mode : false
# 18/11/15 03:36:37 INFO mapreduce.Job:  map 0% reduce 0%
# 18/11/15 03:36:54 INFO mapreduce.Job:  map 44% reduce 0%
# 18/11/15 03:37:00 INFO mapreduce.Job:  map 60% reduce 0%
# 18/11/15 03:37:04 INFO mapreduce.Job:  map 77% reduce 0%
# 18/11/15 03:37:06 INFO mapreduce.Job:  map 83% reduce 0%
# 18/11/15 03:37:10 INFO mapreduce.Job:  map 100% reduce 0%
# 18/11/15 03:37:16 INFO mapreduce.Job:  map 100% reduce 38%
# 18/11/15 03:37:17 INFO mapreduce.Job:  map 100% reduce 50%
# 18/11/15 03:37:18 INFO mapreduce.Job:  map 100% reduce 75%
# 18/11/15 03:37:23 INFO mapreduce.Job:  map 100% reduce 100%
# 18/11/15 03:37:23 INFO mapreduce.Job: Job job_1542235673601_0003 completed successfully
# 18/11/15 03:37:23 INFO mapreduce.Job: Counters: 50
# 	File System Counters
# 		FILE: Number of bytes read=301034906
# 		FILE: Number of bytes written=452849164
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=76874501
# 		HDFS: Number of bytes written=76298115
# 		HDFS: Number of read operations=30
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=16
# 	Job Counters
# 		Killed reduce tasks=1
# 		Launched map tasks=2
# 		Launched reduce tasks=8
# 		Data-local map tasks=2
# 		Total time spent by all maps in occupied slots (ms)=55718
# 		Total time spent by all reduces in occupied slots (ms)=62451
# 		Total time spent by all map tasks (ms)=55718
# 		Total time spent by all reduce tasks (ms)=62451
# 		Total vcore-milliseconds taken by all map tasks=55718
# 		Total vcore-milliseconds taken by all reduce tasks=62451
# 		Total megabyte-milliseconds taken by all map tasks=57055232
# 		Total megabyte-milliseconds taken by all reduce tasks=63949824
# 	Map-Reduce Framework
# 		Map input records=4100
# 		Map output records=6971026
# 		Map output bytes=136541430
# 		Map output materialized bytes=150483590
# 		Input split bytes=228
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=3472295
# 		Reduce shuffle bytes=150483590
# 		Reduce input records=6971026
# 		Reduce output records=3472295
# 		Spilled Records=20913078
# 		Shuffled Maps =16
# 		Failed Shuffles=0
# 		Merged Map outputs=16
# 		GC time elapsed (ms)=1453
# 		CPU time spent (ms)=109480
# 		Physical memory (bytes) snapshot=2212290560
# 		Virtual memory (bytes) snapshot=20222115840
# 		Total committed heap usage (bytes)=1507328000
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=76874273
# 	File Output Format Counters
# 		Bytes Written=76298115
# 18/11/15 03:37:23 INFO streaming.StreamJob: Output directory: week_6_tf_idf_a_1542252986088087
# 18/11/15 03:37:25 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/11/15 03:37:26 INFO client.RMProxy: Connecting to ResourceManager at /0.0.0.0:8032
# 18/11/15 03:37:26 INFO mapred.FileInputFormat: Total input files to process : 8
# 18/11/15 03:37:26 INFO mapreduce.JobSubmitter: number of splits:8
# 18/11/15 03:37:26 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1542235673601_0004
# 18/11/15 03:37:27 INFO impl.YarnClientImpl: Submitted application application_1542235673601_0004
# 18/11/15 03:37:27 INFO mapreduce.Job: The url to track the job: http://81fb89c3c837:8088/proxy/application_1542235673601_0004/
# 18/11/15 03:37:27 INFO mapreduce.Job: Running job: job_1542235673601_0004
# 18/11/15 03:37:37 INFO mapreduce.Job: Job job_1542235673601_0004 running in uber mode : false
# 18/11/15 03:37:37 INFO mapreduce.Job:  map 0% reduce 0%
# 18/11/15 03:37:44 INFO mapreduce.Job:  map 50% reduce 0%
# 18/11/15 03:37:45 INFO mapreduce.Job:  map 75% reduce 0%
# 18/11/15 03:37:49 INFO mapreduce.Job:  map 88% reduce 0%
# 18/11/15 03:37:50 INFO mapreduce.Job:  map 100% reduce 0%
# 18/11/15 03:38:01 INFO mapreduce.Job:  map 100% reduce 67%
# 18/11/15 03:38:07 INFO mapreduce.Job:  map 100% reduce 73%
# 18/11/15 03:38:13 INFO mapreduce.Job:  map 100% reduce 84%
# 18/11/15 03:38:19 INFO mapreduce.Job:  map 100% reduce 95%
# 18/11/15 03:38:22 INFO mapreduce.Job:  map 100% reduce 100%
# 18/11/15 03:38:22 INFO mapreduce.Job: Job job_1542235673601_0004 completed successfully
# 18/11/15 03:38:22 INFO mapreduce.Job: Counters: 50
# 	File System Counters
# 		FILE: Number of bytes read=97131908
# 		FILE: Number of bytes written=195522552
# 		FILE: Number of read operations=0
# 		FILE: Number of large read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=76299147
# 		HDFS: Number of bytes written=46316678
# 		HDFS: Number of read operations=27
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Killed map tasks=1
# 		Launched map tasks=8
# 		Launched reduce tasks=1
# 		Data-local map tasks=8
# 		Total time spent by all maps in occupied slots (ms)=42276
# 		Total time spent by all reduces in occupied slots (ms)=35174
# 		Total time spent by all map tasks (ms)=42276
# 		Total time spent by all reduce tasks (ms)=35174
# 		Total vcore-milliseconds taken by all map tasks=42276
# 		Total vcore-milliseconds taken by all reduce tasks=35174
# 		Total megabyte-milliseconds taken by all map tasks=43290624
# 		Total megabyte-milliseconds taken by all reduce tasks=36018176
# 	Map-Reduce Framework
# 		Map input records=3472295
# 		Map output records=6944590
# 		Map output bytes=83242713
# 		Map output materialized bytes=97131950
# 		Input split bytes=1032
# 		Combine input records=0
# 		Combine output records=0
# 		Reduce input groups=423274
# 		Reduce shuffle bytes=97131950
# 		Reduce input records=6944590
# 		Reduce output records=423273
# 		Spilled Records=13889180
# 		Shuffled Maps =8
# 		Failed Shuffles=0
# 		Merged Map outputs=8
# 		GC time elapsed (ms)=1550
# 		CPU time spent (ms)=67050
# 		Physical memory (bytes) snapshot=2611593216
# 		Virtual memory (bytes) snapshot=18089496576
# 		Total committed heap usage (bytes)=1805647872
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# 	File Input Format Counters
# 		Bytes Read=76298115
# 	File Output Format Counters
# 		Bytes Written=46316678
# 18/11/15 03:38:22 INFO streaming.StreamJob: Output directory: week_6_tf_idf_b_1542252986089593
